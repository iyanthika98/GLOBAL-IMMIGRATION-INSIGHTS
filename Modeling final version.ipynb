# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
dff= pd.read_csv('MIG.csv')

# Display the first few rows of the dataframe
print("First few rows of the dataset:")
print(dff.head())
# Out:
# First few rows of the dataset:
#    CO2 Country of birth/nationality  \
# 0  AFG                  Afghanistan
# 1  AFG                  Afghanistan
# 2  AFG                  Afghanistan
# 3  AFG                  Afghanistan
# 4  AFG                  Afghanistan
#
#                                        Variable    Country  Year  Value
# 0  Inflows of foreign population by nationality  Australia  2000    887
# 1  Inflows of foreign population by nationality  Australia  2001    456
# 2  Inflows of foreign population by nationality  Australia  2002    660
# 3  Inflows of foreign population by nationality  Australia  2003   1015
# 4  Inflows of foreign population by nationality  Australia  2004   1340

# %%
sample_df = dff.sample(frac=0.15, random_state=42)

print(sample_df)
# Out:
#         CO2 Country of birth/nationality  \
# 69147   GEO                      Georgia
# 332353  LAO                         Laos
# 296464  TZA                     Tanzania
# 147503  LCA                  Saint Lucia
# 189055  ZMB                       Zambia
# ...     ...                          ...
# 411959  WSM                        Samoa
# 74583   GTM                    Guatemala
# 306109  SYC                   Seychelles
# 268640  CHN                        China
# 256289  CAN                       Canada
#
#                                                  Variable     Country  Year  \
# 69147        Inflows of foreign population by nationality       Japan  2013
# 332353         Stock of foreign population by nationality       Korea  2012
# 296464  Stock of foreign-born population by country of...    Slovenia  2005
# 147503       Inflows of foreign population by nationality      France  2020
# 189055       Inflows of foreign population by nationality       Italy  2003
# ...

# %%
sample_df.head(5)
# Out:
#         CO2 Country of birth/nationality  \
# 69147   GEO                      Georgia
# 332353  LAO                         Laos
# 296464  TZA                     Tanzania
# 147503  LCA                  Saint Lucia
# 189055  ZMB                       Zambia
#
#                                                  Variable   Country  Year  \
# 69147        Inflows of foreign population by nationality     Japan  2013
# 332353         Stock of foreign population by nationality     Korea  2012
# 296464  Stock of foreign-born population by country of...  Slovenia  2005
# 147503       Inflows of foreign population by nationality    France  2020
# 189055       Inflows of foreign population by nationality     Italy  2003
#
#         Value
# 69147      61
# 332353    235
# 296464      1
# 147503     66
# 189055     16

# %%
sample_df = sample_df.rename(columns={'Country of birth/nationality': 'nationality_country', 'Country': 'migration_country', 'CO2': 'Country_code'})

# %%
# Load the dataset
df = pd.read_excel(r'D:\SEMESTER_4\v3.xlsx')

# Display the first few rows of the dataframe
print("First few rows of the dataset:")
print(df.head())
# Out:
# First few rows of the dataset:
#   Country_code nationality_country  \
# 0          CMR            Cameroon
# 1          PRT            Portugal
# 2          NIC           Nicaragua
# 3          FRA              France
# 4          IDN           Indonesia
#
#                                             Variable  Year_x  Value  \
# 0  Acquisition of nationality by country of forme...    2007    243
# 1  Acquisition of nationality by country of forme...    2007   2506
# 2       Inflows of foreign population by nationality    2007     30
# 3  Acquisition of nationality by country of forme...    2011      8
# 4      Outflows of foreign population by nationality    2021      3
#
#     Population  hci_Rank  hci_index migration_country
# 0   27914536.0       144       0.40            Canada
# 1   10409704.0        17       0.77     United States
# 2    6948392.0       104       0.51            Sweden
# 3   67971311.0        18       0.76            Greece
# ...

# %%
# Basic statistics for numerical columns
basic_stats = df.describe()

# Distribution of the 'Year_x' column
year_distribution = df['Year_x'].value_counts().sort_index()

# Check for missing values
missing_values = df.isnull().sum()

basic_stats, year_distribution, missing_values
# Out:
# (             Year_x         Value    Population      hci_Rank     hci_index
#  count  59139.000000  5.913900e+04  5.704600e+04  59139.000000  59139.000000
#  mean    2011.837417  7.303116e+03  4.906950e+07     82.319704      0.570078
#  std        6.137891  8.498391e+04  1.705194e+08     48.234325      0.138523
#  min     2000.000000  0.000000e+00  1.131200e+04      1.000000      0.290000
#  25%     2007.000000  3.000000e+00  2.831639e+06     40.000000      0.450000
#  50%     2012.000000  4.700000e+01  1.040970e+07     81.000000      0.580000
#  75%     2017.000000  6.010000e+02  3.564810e+07    124.000000      0.680000
#  max     2022.000000  1.126991e+07  1.417173e+09    168.000000      0.880000,
#  2000    1691
#  2001    1760
#  2002    1929
#  2003    1917
#  2004    1905
#  2005    2099
#  2006    2184
#  2007    2364
#  2008    2683
#  2009    2777
#  2010    2857
#  2011    3017
#  2012    3088
#  2013    3058
#  2014    3090
#  2015    3071
#  2016    3112
#  2017    3231
# ...

# %%
egypt_population_impute_value = 114078467

# Apply the imputation
df.loc[(df['nationality_country'] == 'Egypt') & (df['Population'].isnull()), 'Population'] = egypt_population_impute_value

# Check if there are still any missing values for Egypt
missing_population_egypt_after_specific_imputation = df[df['nationality_country'] == 'Egypt']['Population'].isnull().sum()
missing_population_egypt_after_specific_imputation
# Out:
# 0

# %%
Eswatini_population_impute_value = 1219498


# Apply the imputation
df.loc[(df['nationality_country'] == 'Eswatini') & (df['Population'].isnull()), 'Population'] = Eswatini_population_impute_value

# Check if there are still any missing values for Egypt
missing_population_Eswatinit_after_specific_imputation = df[df['nationality_country'] == 'Eswatini']['Population'].isnull().sum()
missing_population_Eswatinit_after_specific_imputation
# Out:
# 0

# %%
Congo_population_impute_value = 6212861



# Apply the imputation
df.loc[(df['nationality_country'] == 'Congo') & (df['Population'].isnull()), 'Population'] = Congo_population_impute_value

missing_population_Congo_after_specific_imputation = df[df['nationality_country'] == 'Congo']['Population'].isnull().sum()
missing_population_Congo_after_specific_imputation
# Out:
# 0

# %%
Yemen_population_impute_value = 35042652



# Apply the imputation
df.loc[(df['nationality_country'] == 'Yemen') & (df['Population'].isnull()), 'Population'] = Yemen_population_impute_value

missing_population_Yemen_after_specific_imputation = df[df['nationality_country'] == 'Yemen']['Population'].isnull().sum()
missing_population_Yemen_after_specific_imputation
# Out:
# 0

# %%
Iran_population_impute_value = 89664036




# Apply the imputation
df.loc[(df['nationality_country'] == 'Iran') & (df['Population'].isnull()), 'Population'] = Iran_population_impute_value

missing_population_Iran_after_specific_imputation = df[df['nationality_country'] == 'Iran']['Population'].isnull().sum()
missing_population_Iran_after_specific_imputation
# Out:
# 0

# %%
Russia_population_impute_value = 144068116




# Apply the imputation
df.loc[(df['nationality_country'] == 'Russia') & (df['Population'].isnull()), 'Population'] = Russia_population_impute_value

missing_population_Russia_after_specific_imputation = df[df['nationality_country'] == 'Russia']['Population'].isnull().sum()
missing_population_Russia_after_specific_imputation
# Out:
# 0

# %%
df.to_excel(r'D:\SEMESTER_4\v4.xlsx')

# %%
print("Dataset shape:", df.shape)
print(df.info())
print(df.head())
# Out:
# Dataset shape: (59139, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59139 entries, 0 to 59138
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country_code         59139 non-null  object
#  1   nationality_country  59139 non-null  object
#  2   Variable             59139 non-null  object
#  3   Year_x               59139 non-null  int64
#  4   Value                59139 non-null  int64
#  5   Population           59139 non-null  float64
#  6   hci_Rank             59139 non-null  int64
#  7   hci_index            59139 non-null  float64
#  8   migration_country    59139 non-null  object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 4.1+ MB
# None
#   Country_code nationality_country  \
# 0          CMR            Cameroon
# 1          PRT            Portugal
# 2          NIC           Nicaragua
# 3          FRA              France
# 4          IDN           Indonesia
#
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Country_code           0
# nationality_country    0
# Variable               0
# Year_x                 0
# Value                  0
# Population             0
# hci_Rank               0
# hci_index              0
# migration_country      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Frequency of 'Variable' categories
sns.countplot(data=df, x='Variable')
plt.xticks(rotation=45)
plt.show()

# Top 10 `nationality_country` by frequency
df['nationality_country'].value_counts().head(10).plot(kind='bar')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Frequency of 'Variable' categories
sns.countplot(data=df, x='Variable')
plt.xticks(rotation=45)
plt.show()

# Top 10 `nationality_country` by frequency
df['hci_index'].value_counts().head(10).plot(kind='bar')
plt.show()

# %%
# Histogram for 'Value'
df['Value'].hist(bins=50)
plt.show()

# Boxplot for 'hci_index'
sns.boxplot(data=df, x='hci_index')
plt.show()

# %%
# Trends in 'Value' over 'Year_x'
sns.lineplot(data=df, x='Year_x', y='Value', estimator='mean')
plt.show()

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
# Convert 'Year_x' from a numerical to a categorical variable
df['Year_x'] = df['Year_x'].astype('category')

# Verify the change in data type
print(df['Year_x'].dtype)
# Out:
# category

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histograms for numerical variables
df.hist(bins=15, figsize=(15, 10), layout=(2, 3))
plt.tight_layout()
plt.show()

# %%
# Count plots for categorical variables
for column in df.select_dtypes(include=['object','category']).columns:
    sns.countplot(y=column, data=df)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
# Scatter plot for two numerical variables, and box plots for categorical vs numerical variables
sns.scatterplot(data=df, x='Population', y='Value')
plt.title('Population vs Value')
plt.show()

sns.boxplot(x='Variable', y='Value', data=df)
plt.xticks(rotation=45)
plt.title('Value Distribution Across Variable Types')
plt.show()

# %%
data = df

# %%
# Assuming the same structure of the dataframe as previously loaded
# Creating the mapping from nationality_country to Population
population_mapping = data.set_index('nationality_country')['Population'].to_dict()

# Apply the mapping to the migration_country column to create a new column
# If a migration_country doesn't have a corresponding nationality_country, NaN will be assigned
data['migration_country_population'] = data['migration_country'].map(population_mapping)

# Showing the head of the dataframe to verify the new column
data[['nationality_country', 'migration_country', 'Population', 'migration_country_population']].head()
# Out:
#   nationality_country migration_country   Population  \
# 0            Cameroon            Canada   27914536.0
# 1            Portugal     United States   10409704.0
# 2           Nicaragua            Sweden    6948392.0
# 3              France            Greece   67971311.0
# 4           Indonesia           Iceland  275501339.0
#
#    migration_country_population
# 0                    38929902.0
# 1                   333287557.0
# 2                    10486941.0
# 3                    10426919.0
# 4                      382003.0

# %%
# Creating a list of labels for the bins for more descriptive naming
bin_labels = [f'Bin_{i+1}' for i in range(8)]

# Recreate the bins with labels
data['migration_country_population_bins'] = pd.cut(
    data['migration_country_population'], 
    bins=8, 
    labels=bin_labels
)

# Showing the head of the dataframe to verify the new binned column with labels
data[['migration_country_population', 'migration_country_population_bins']].head()
# Out:
#    migration_country_population migration_country_population_bins
# 0                    38929902.0                             Bin_1
# 1                   333287557.0                             Bin_8
# 2                    10486941.0                             Bin_1
# 3                    10426919.0                             Bin_1
# 4                      382003.0                             Bin_1

# %%
# Load the data
data_path = r'D:\SEMESTER_4/v6.csv'
data = pd.read_csv(data_path)
# Display the first few rows of the dataframe to understand its structure
data.head()
# Out:
#   Country_code nationality_country  \
# 0          CMR            Cameroon
# 1          PRT            Portugal
# 2          NIC           Nicaragua
# 3          FRA              France
# 4          IDN           Indonesia
#
#                                             Variable  Year_x  Value  \
# 0  Acquisition of nationality by country of forme...    2007    243
# 1  Acquisition of nationality by country of forme...    2007   2506
# 2       Inflows of foreign population by nationality    2007     30
# 3  Acquisition of nationality by country of forme...    2011      8
# 4      Outflows of foreign population by nationality    2021      3
#
#    Population  hci_Rank  hci_index migration_country  hdi_index  \
# 0    27914536       144       0.40            Canada      0.587
# 1    10409704        17       0.77     United States      0.874
# 2     6948392       104       0.51            Sweden      0.669
# 3    67971311        18       0.76            Greece      0.910
# ...

# %%
df=data

# %%
print(data.columns)
# Out:
# Index(['Country_code', 'nationality_country', 'Variable', 'Year_x', 'Value',
#        'Population', 'hci_Rank', 'hci_index', 'migration_country', 'hdi_index',
#        'migration_country_population', 'migration_country_population_bins'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
import pandas as pd


# Specify categorical and numerical columns
categorical_cols = ['Country_code', 'nationality_country', 'Variable', 'Year_x', 'migration_country_population_bins']
numerical_cols = ['Value', 'Population', 'hci_Rank', 'hci_index', 'hdi_index', 'migration_country_population']

# Preprocessing for numerical data
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)])

# Define the target variable and encode it
y = LabelEncoder().fit_transform(df['migration_country'])
X = df.drop('migration_country', axis=1)

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
pip install some_library
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement some_library (from versions: none)
# ERROR: No matching distribution found for some_library

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

logistic_model = Pipeline(steps=[('preprocessor', preprocessor),
                                 ('classifier', LogisticRegression(max_iter=1000))])
logistic_model.fit(X_train, y_train)
logistic_preds = logistic_model.predict(X_test)
print('Logistic Regression Accuracy:', accuracy_score(y_test, logistic_preds))
# Out:
# Logistic Regression Accuracy: 0.5122590463307406

# %%
from sklearn.svm import SVC

svm_model = Pipeline(steps=[('preprocessor', preprocessor),
                            ('classifier', SVC())])
svm_model.fit(X_train, y_train)
svm_preds = svm_model.predict(X_test)
print('SVM Accuracy:', accuracy_score(y_test, svm_preds))
# Out:
# SVM Accuracy: 0.44538383496787287

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = Pipeline(steps=[('preprocessor', preprocessor),('classifier', KNeighborsClassifier())])
knn_model.fit(X_train, y_train)
knn_preds = knn_model.predict(X_test)
print('KNN Accuracy:', accuracy_score(y_test, knn_preds))
# Out:
# C:\Users\Gaming\Anacond\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNN Accuracy: 0.6279168075752452

# %%
from sklearn.preprocessing import FunctionTransformer
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Add a step in the pipeline to convert sparse matrix to dense
to_dense_transformer = FunctionTransformer(lambda x: x.toarray(), accept_sparse=True)

naive_bayes_model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('to_dense', to_dense_transformer),  # Add this step before the classifier
    ('classifier', GaussianNB())
])

naive_bayes_model.fit(X_train, y_train)
naive_bayes_preds = naive_bayes_model.predict(X_test)
print('Naive Bayes Accuracy:', accuracy_score(y_test, naive_bayes_preds))
# Out:
# Naive Bayes Accuracy: 0.9041258031788976

# %%
from sklearn.ensemble import AdaBoostClassifier

ada_boost_model = Pipeline(steps=[('preprocessor', preprocessor),
                                  ('classifier', AdaBoostClassifier(random_state=42))])
ada_boost_model.fit(X_train, y_train)
ada_boost_preds = ada_boost_model.predict(X_test)
print('AdaBoost Classifier Accuracy:', accuracy_score(y_test, ada_boost_preds))
# Out:
# AdaBoost Classifier Accuracy: 0.24856273249915456

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest_model = Pipeline(steps=[('preprocessor', preprocessor),('classifier', RandomForestClassifier(n_estimators=100, random_state=42))])
random_forest_model.fit(X_train, y_train)
random_forest_preds = random_forest_model.predict(X_test)
print('Random Forest Classifier Accuracy:', accuracy_score(y_test, random_forest_preds))
# Out:
# Random Forest Classifier Accuracy: 0.7496618194115657
